# %%
# %cd /content/drive/MyDrive/StanfordCS224N/hw/a4
# Out:
# /content/drive/MyDrive/StanfordCS224N/hw/a4

# %%
# %pip install -r gpu_requirements.txt
# Out:
# ...
#      |████████████████████████████████| 51kB 2.8MB/s
# ...
# ERROR: spacy 2.2.4 has requirement tqdm<5.0.0,>=4.38.0, but you'll have tqdm 4.29.1 which is incompatible.
# ERROR: fbprophet 0.7.1 has requirement tqdm>=4.36.1, but you'll have tqdm 4.29.1 which is incompatible.
# ...
#   Found existing installation: tqdm 4.41.1
#     Uninstalling tqdm-4.41.1:
#       Successfully uninstalled tqdm-4.41.1
# ...

# %%
# !sh run.sh train
# Out:
# Streaming output truncated to the last 5000 lines.
# epoch 6, iter 39170, avg. loss 35.32, avg. ppl 6.98 cum. examples 37440, speed 8681.51 words/sec, time elapsed 2756.90 sec
# epoch 6, iter 39180, avg. loss 35.56, avg. ppl 7.73 cum. examples 37760, speed 8165.10 words/sec, time elapsed 2757.59 sec
# epoch 6, iter 39190, avg. loss 35.35, avg. ppl 7.38 cum. examples 38080, speed 8451.14 words/sec, time elapsed 2758.26 sec
# epoch 6, iter 39200, avg. loss 35.49, avg. ppl 7.18 cum. examples 38400, speed 8040.79 words/sec, time elapsed 2758.97 sec
# epoch 6, iter 39210, avg. loss 35.32, avg. ppl 6.65 cum. examples 38720, speed 8377.60 words/sec, time elapsed 2759.68 sec
# epoch 6, iter 39220, avg. loss 35.84, avg. ppl 7.57 cum. examples 39040, speed 8483.83 words/sec, time elapsed 2760.35 sec
# epoch 6, iter 39230, avg. loss 33.71, avg. ppl 6.61 cum. examples 39360, speed 8068.27 words/sec, time elapsed 2761.06 sec
# ...

# %%
# !sh run.sh test
# Out:
# load test source sentences from [./en_es_data/test.es]
# load test target sentences from [./en_es_data/test.en]
# load model from model.bin
# Decoding: 100% 8064/8064 [04:59<00:00, 26.89it/s]
# Corpus BLEU: 22.585697045551246

# %%
# %cd /content/drive/MyDrive/StanfordCS224N/hw/a5
# Out:
# /content/drive/MyDrive/StanfordCS224N/hw/a5

# %%
# !sh run.sh test
# Out:
# load test source sentences from [./en_es_data/test.es]
# load test target sentences from [./en_es_data/test.en]
# load model from model.bin
# Decoding: 100% 8064/8064 [09:57<00:00, 13.50it/s]
# Corpus BLEU: 23.883556438501635

# %%
# !sh run.sh test
# Out:
# load test source sentences from [./en_es_data/test.es]
# load test target sentences from [./en_es_data/test.en]
# load model from model.bin
# Decoding: 100% 8064/8064 [09:28<00:00, 14.18it/s]
# Corpus BLEU: 24.025619953967603

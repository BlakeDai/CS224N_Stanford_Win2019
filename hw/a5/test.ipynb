# %%
# %cd /content/drive/MyDrive/StanfordCS224N/hw/a5
# Out:
# /content/drive/MyDrive/StanfordCS224N/hw/a5

# %%
pip install -r gpu_requirements.txt
# Out:
# ...
#      |████████████████████████████████| 51kB 5.2MB/s
# ...
# ERROR: spacy 2.2.4 has requirement tqdm<5.0.0,>=4.38.0, but you'll have tqdm 4.29.1 which is incompatible.
# ERROR: fbprophet 0.7.1 has requirement tqdm>=4.36.1, but you'll have tqdm 4.29.1 which is incompatible.
# ...
#   Found existing installation: tqdm 4.41.1
#     Uninstalling tqdm-4.41.1:
#       Successfully uninstalled tqdm-4.41.1
# ...

# %%
# !sh run.sh train
# Out:
# Streaming output truncated to the last 5000 lines.
# epoch 18, iter 120730, avg. loss 95.23, avg. ppl 183.46 cum. examples 23360, speed 5335.67 words/sec, time elapsed 12309.05 sec
# epoch 18, iter 120740, avg. loss 87.48, avg. ppl 169.98 cum. examples 23680, speed 5395.08 words/sec, time elapsed 12310.06 sec
# epoch 18, iter 120750, avg. loss 88.47, avg. ppl 159.12 cum. examples 24000, speed 5436.93 words/sec, time elapsed 12311.08 sec
# epoch 18, iter 120760, avg. loss 86.31, avg. ppl 153.03 cum. examples 24320, speed 5959.72 words/sec, time elapsed 12312.00 sec
# epoch 18, iter 120770, avg. loss 91.89, avg. ppl 157.24 cum. examples 24640, speed 5928.73 words/sec, time elapsed 12312.98 sec
# epoch 18, iter 120780, avg. loss 87.93, avg. ppl 152.00 cum. examples 24960, speed 5427.82 words/sec, time elapsed 12314.02 sec
# epoch 18, iter 120790, avg. loss 96.75, avg. ppl 173.54 cum. examples 25280, speed 5499.05 words/sec, time elapsed 12315.11 sec
# ...
